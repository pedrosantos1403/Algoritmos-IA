# %% [markdown]
# Nome: Pedro Santos Oliveira e Vinícius Nascimento
# Algoritmo Genético - Laboratório IA

# %% [markdown]
# Foi implementado o método de seleção da roleta, o método de crossover aritmético e o método de mutação
# considerando a mutação do gene entre 90% e 110% do seu valor atual nunca ultrapassando o máximo valor possível.

# %%
import Population

# %%
# Executing the AG logic
Population.main()
