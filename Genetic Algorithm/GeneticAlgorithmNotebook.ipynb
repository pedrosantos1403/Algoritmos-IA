# %% [markdown]
# Nome: Pedro Santos Oliveira e Vinícius Nascimento
# Algoritmo Genético - Laboratório IA

# %%
import Population

# %%
# Executing the AG logic
Population.main()
# Out:
# Melhor valor final:  13.683172850281954
# Pior valor final:  4.511073743143165

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(Population.best_individuals)
plt.plot(Population.worst_individuals)
plt.plot(Population.mean_individuals)
